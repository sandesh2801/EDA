# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\hp\Documents\Data Science\Naresh IT\EDA with Python\Visadataset - Visadataset.csv")
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %% [markdown]
# **Data Transformation**

# %% [markdown]
# - Log transformtion
# - Exponential transformation
# - Reciprocal transformation
# - Square Root transformstion
# - Power transformation

# %% [markdown]
# **Step-1**
#
# - Import packages, numpy and matplotlib

# %% [markdown]
# **Step-2**
# - take random data

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.163144  , 0.52360516, 0.81557228, ..., 0.11576248, 2.03746593,
#        1.71936737])

# %%
plt.hist(exp_data,bins=40)
plt.show()

# %% [markdown]
# **Step-3**
#
# - COvert exp_data to Normal distribution
# - bins=intervsl

# %% [markdown]
# **Step-4**
#
# - Log Transformation
#
# - Log transformation means performing log operations
# - Log means natural logarithm base=e

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([-1.81312205, -0.64701739, -0.20386523, ..., -2.15621479,
#         0.71170684,  0.54195641])

# %%
plt.hist(log_data,bins=20,label='Logarithm')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=30,label='Logarithm')
plt.legend()
plt.show()

# %% [markdown]
# **Reciprocal Transformation**

# %%
x=2
1/x
# Out:
# 0.5

# %%
reciprocal_data=np.reciprocal(exp_data)
plt.hist(reciprocal_data,bins=20,label='Reciprocal')
# Out:
# (array([9.963e+03, 2.200e+01, 3.000e+00, 5.000e+00, 0.000e+00, 2.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([8.91264240e-02, 3.49151680e+02, 6.98214233e+02, 1.04727679e+03,
#         1.39633934e+03, 1.74540189e+03, 2.09446445e+03, 2.44352700e+03,
#         2.79258955e+03, 3.14165211e+03, 3.49071466e+03, 3.83977722e+03,
#         4.18883977e+03, 4.53790232e+03, 4.88696488e+03, 5.23602743e+03,
#         5.58508998e+03, 5.93415254e+03, 6.28321509e+03, 6.63227764e+03,
#         6.98134020e+03]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **SquareRoot **

# %%
square_root_data=np.sqrt(exp_data)
plt.hist(square_root_data,bins=20,label="Square Root Data")
plt.legend()

# %%
plt.figure(figsize=(10,3))
log_data=np.log(exp_data)
plt.subplot(1,3,1).hist(exp_data,bins=20,label='Expoential')
plt.legend()
plt.subplot(1,3,2).hist(log_data,bins=20,label='Logarithm')
plt.legend()
square_data=np.sqrt(exp_data)
plt.subplot(1,3,3).hist(square_data,bins=20,label='Square')
plt.legend()

# %% [markdown]
# **Power Transformation**
# - Box Cox
#
# - ye-johnson
#
# - It is under sklearn preprocessing

# %% [markdown]
# x^lambda-1/lambda   #box-cox formula

# %%
import numpy as np
from sklearn.preprocessing import PowerTransformer
power=PowerTransformer(method='yeo-johnson',standardize=True)
data_trans=power.fit_transform(exp_data.reshape(-1,1))
plt.hist(data_trans)
# Out:
# (array([1147., 1184., 1334., 1391., 1418., 1309., 1095.,  786.,  297.,
#           39.]),
#  array([-1.75941826e+00, -1.31914827e+00, -8.78878277e-01, -4.38608284e-01,
#          1.66170927e-03,  4.41931703e-01,  8.82201696e-01,  1.32247169e+00,
#          1.76274168e+00,  2.20301168e+00,  2.64328167e+00]),
#  <BarContainer object of 10 artists>)

# %%
exp_data.reshape(-1,1)   # expecting [[]], so giving error
# Out:
# array([[0.163144  ],
#        [0.52360516],
#        [0.81557228],
#        ...,
#        [0.11576248],
#        [2.03746593],
#        [1.71936737]])
