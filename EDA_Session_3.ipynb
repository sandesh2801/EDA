# %% [markdown]
# **Import required packages**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Read the Data**

# %%
names=["Ayush",'avinash','akash','Sandesh','Aadesh','Aaron']
age=[20,25,30,89,90,89]
p=pd.DataFrame(zip(names,age),columns=['Name','Age'])
p
# Out:
#       Name  Age
# 0    Ayush   20
# 1  avinash   25
# 2    akash   30
# 3  Sandesh   89
# 4   Aadesh   90
# 5    Aaron   89

# %% [markdown]
# **Head**
# - top 5 rows

# %%
p.head()
# Out:
#       Name  Age
# 0    Ayush   20
# 1  avinash   25
# 2    akash   30
# 3  Sandesh   89
# 4   Aadesh   90

# %% [markdown]
# **Tail**
# - last 5 rows

# %%
p.tail()
# Out:
#       Name  Age
# 1  avinash   25
# 2    akash   30
# 3  Sandesh   89
# 4   Aadesh   90
# 5    Aaron   89

# %% [markdown]
# **Shape**

# %%
p.shape
# Out:
# (6, 2)

# %%
print("The numbers of rows",p.shape[0])
print("The number of columns",p.shape[1])
# Out:
# The numbers of rows 6
# The number of columns 2

# %% [markdown]
# **Size**

# %% [markdown]
# - no of rows* no of columns

# %%
p.size    # 6*2=12
# Out:
# 12

# %% [markdown]
# **Columns**

# %%
p.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %% [markdown]
# $dtypes$

# %%
p.dtypes             # object == categorical,  int64= numerical
# Out:
# Name    object
# Age      int64
# dtype: object

# %%
# visa_df is of Dataframe
# visa_df dtypes is a series

# %%
# if lines then series

# %%
#Series object can be converted into dictonery

# %%
# after that you can use dictionary methods

# %% [markdown]
# **Task: create categorical column list, and numerical column list**

# %%
- convert

# %% [markdown]
# $$is NUll$$

# %% [markdown]
# - used to identify any missing values
# - if null asking question to computer
# - it will give true or false
# - yes value is missed
# - no vale is not missed

# %%
is na is null   drop duplicates   info

# %%
visa_df=pd.read_csv(r"C:\Users\hp\Documents\Data Science\Naresh IT\EDA with Python\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300],axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 visa_df.take([100,200,300],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
visa_df.take([2,5,7],axis=1)    # techincally educationof employee is 3rd column
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.take([100:105])
# Out:
#   Cell In[13], line 1
#     visa_df.take([100:105])
#                      ^
# SyntaxError: invalid syntax

# %%
#drawback
# i need 100,200 300 th rows with just 2,5,7 column
# possible, but with 2 take needed

# %%
visa_df.take([100,200,300]).take([2,5,7],axis=1)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %% [markdown]
# $iloc$

# %%
# visa_df.iloc[<rows>,<columns>]
# visa_df[<start:end>,<start:end>]

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
#now slicing
visa_df.iloc[100:105,2:5]
# Out:
#     education_of_employee has_job_experience requires_job_training
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N

# %%
visa_df.iloc[[100,200,300]]          # same like take, all columns
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[100:105,[2,5,7]]          # khatarnak, game changer
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[[100,200,300],[2]]
# Out:
#     education_of_employee
# 100              Master's
# 200             Doctorate
# 300              Master's

# %%
visa_df.iloc[[100,200,300],2]
# Out:
# 100     Master's
# 200    Doctorate
# 300     Master's
# Name: education_of_employee, dtype: object

# %%
visa_df.iloc[[5]]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.iloc[5]
# Out:
# case_id                     EZYV06
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2339
# yr_of_estab                   2012
# region_of_employment         South
# prevailing_wage           78252.14
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 5, dtype: object

# %%
visa_df.iloc[[5],:]
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.iloc[5,:]        # no bracket ---> series
# Out:
# case_id                     EZYV06
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2339
# yr_of_estab                   2012
# region_of_employment         South
# prevailing_wage           78252.14
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 5, dtype: object

# %%
visa_df.iloc[[5],0:]        # bracket is there---> dataframe
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 5         78252.14         Year                  Y   Certified

# %%
# all employees column
visa_df.iloc[:,[5]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
# without checking do

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
cols=list(visa_df.columns)
cols
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols.index('no_of_employees')
# Out:
# 5

# %%
# all employees column
visa_df.iloc[:,[cols.index('no_of_employees')]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %% [markdown]
# **loc**

# %% [markdown]
# - loc will take direclty the column names

# %%
visa_df.loc[[100,200,300],['no_of_employees']]
# Out:
#      no_of_employees
# 100             2227
# 200             3282
# 300             3268
